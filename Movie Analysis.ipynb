# %%
import numpy as np
import pandas as pd

# %%
Dataset = pd.read_csv("imdb-movies-dataset.csv")

# %%
print(Dataset.head())
# Out:
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1  https://m.media-amazon.com/images/M/MV5BZGI4NT...
# 2  https://m.media-amazon.com/images/M/MV5BZjIyOT...
# 3  https://m.media-amazon.com/images/M/MV5BMjA5Zj...
# 4  https://m.media-amazon.com/images/M/MV5BNTk1MT...
#
#                                Title    Year Certificate  Duration (min)  \
# 0                    The Idea of You  2023.0           R           115.0
# 1  Kingdom of the Planet of the Apes  2023.0       PG-13           145.0
# 2                          Unfrosted  2023.0       PG-13            97.0
# 3                       The Fall Guy  2023.0       PG-13           126.0
# 4                        Challengers  2023.0           R           131.0
#
#                         Genre  Rating  Metascore           Director  \
# 0      Comedy, Drama, Romance     6.4       67.0  Michael Showalter
# ...

# %%
oldest_year = Dataset['Year'].min()
oldest_movie = Dataset.loc[Dataset['Year'] == oldest_year]

# %%
print(oldest_movie)
# Out:
#                                                  Poster  \
# 9900  https://m.media-amazon.com/images/M/MV5BN2I2NG...
# 9901  https://m.media-amazon.com/images/M/MV5BMTM1Nz...
# 9902  https://m.media-amazon.com/images/M/MV5BMTkwMT...
# 9903  https://m.media-amazon.com/images/M/MV5BMTM0MT...
# 9904  https://m.media-amazon.com/images/M/MV5BN2RlOT...
# 9905  https://m.media-amazon.com/images/M/MV5BNjYwND...
# 9906  https://m.media-amazon.com/images/M/MV5BMzE2ZD...
# 9907  https://m.media-amazon.com/images/M/MV5BY2QyYT...
# 9908  https://m.media-amazon.com/images/M/MV5BZjJmOT...
# 9909  https://m.media-amazon.com/images/M/MV5BMjA5OT...
# 9910  https://m.media-amazon.com/images/M/MV5BYjE2OT...
# 9911  https://m.media-amazon.com/images/M/MV5BMTA3Mj...
# 9912  https://m.media-amazon.com/images/M/MV5BMTc1Mj...
# 9913  https://m.media-amazon.com/images/M/MV5BNzU4ZG...
# 9914  https://m.media-amazon.com/images/M/MV5BYTFiNW...
# 9915  https://m.media-amazon.com/images/M/MV5BODMwNm...
# ...

# %%
certificates = Dataset['Certificate'].unique()
num_certificates = len(certificates)

print(type(certificates))
print(certificates)
print(num_certificates)
# Out:
# <class 'numpy.ndarray'>
# ['R' 'PG-13' nan 'A' 'PG' 'UA' 'U' 'UA 16+' '16' '(Banned)' '18'
#  'Not Rated' '15+' 'UA 7+' '13' 'UA 13+' 'All' '12+' '7' 'U/A 16+' 'U/A'
#  'Approved' 'G' 'Unrated' '12' 'NC-17' 'M/PG' '18+' 'GP' '16+' 'X']
# 31

# %%
banned_mov = Dataset.loc[Dataset['Certificate'] == '(Banned)']
print(banned_mov)
# Out:
#                                                  Poster  \
# 207   https://m.media-amazon.com/images/M/MV5BMjE1MT...
# 1187  https://m.media-amazon.com/images/M/MV5BMTczND...
# 1247  https://m.media-amazon.com/images/M/MV5BOGU4Mj...
# 1261  https://m.media-amazon.com/images/M/MV5BMjIxMj...
# 1365  https://m.media-amazon.com/images/M/MV5BYzgzMT...
# 4840  https://m.media-amazon.com/images/M/MV5BNzE3Mz...
# 5174  https://m.media-amazon.com/images/M/MV5BYjRhNW...
# 6431  https://m.media-amazon.com/images/M/MV5BNTg1MD...
# 7279  https://m.media-amazon.com/images/M/MV5BYjNkYz...
# 7776  https://m.media-amazon.com/images/M/MV5BMjI0Mz...
# 7961  https://m.media-amazon.com/images/M/MV5BMjA2MT...
# 8049  https://m.media-amazon.com/images/M/MV5BYzFhND...
#
#                                      Title    Year Certificate  \
# 207                   Fifty Shades of Grey  1995.0    (Banned)
# 1187       The Girl with the Dragon Tattoo  2005.0    (Banned)
# ...

# %%
genre = Dataset['Genre'].unique()

print(genre)
print(len(genre))
# Out:
# ['Comedy, Drama, Romance' 'Action, Adventure, Sci-Fi'
#  'Biography, Comedy, History' 'Action, Comedy, Drama'
#  'Drama, Romance, Sport' 'Horror, Thriller' 'Action, Adventure, Thriller'
#  'Comedy, Romance' 'Action, Drama, War' 'Action, Adventure, Drama'
#  'Adventure, Comedy, Fantasy' 'Action, Adventure, Crime'
#  'Crime, Drama, Mystery' 'Animation, Comedy, Drama' 'Drama, Sci-Fi'
#  'Horror' 'Comedy, Drama' 'Action, Comedy, Sci-Fi' 'Action, Thriller'
#  'Action, Adventure, Fantasy' 'Action, Horror, Thriller'
#  'Action, Comedy, Thriller' 'Drama, Romance' 'Action, Drama, Sci-Fi'
#  'Biography, Drama, History' 'Biography, Drama, Sport'
#  'Biography, Drama, Music' 'Documentary, Comedy'
#  'Horror, Mystery, Thriller' 'Animation, Adventure, Comedy'
#  'Action, Crime' 'Action, Crime, Fantasy' 'Animation, Action, Adventure'
#  'Drama, History, War' 'Crime, Drama' 'Adventure, Sci-Fi'
#  'Action, Crime, Thriller' 'Drama, Mystery, Romance'
# ...
